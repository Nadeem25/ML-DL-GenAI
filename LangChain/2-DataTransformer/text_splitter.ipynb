# %%
# Load and Read the pdf file
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('C:/Notes/ML-DL-GenAI/LangChain/Files/uni-assist.pdf')
pdf_document = loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk-java 3.2.2', 'creationdate': '2025-07-07T11:05:24+02:00', 'moddate': '2025-07-07T11:05:24+02:00', 'source': 'C:/Notes/ML-DL-GenAI/LangChain/Files/uni-assist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content="Nadeem Athar Chaudhary\nBEI KHAN\nAlte Hellersdorfer Str 101\n12629 Berlin\nDEUTSCHLAND\nuni-assist Evaluation Report\nLastname : Chaudhary\nFirstname: Nadeem Athar\nDate of birth: 25.04.1998\nPlace of birth: Mumbai\nNationality: Indien\nApplicant number: 3328737\nThe above named applicant submitted a number of documents to uni-assist for preliminary\nevaluation as part of his or her application to at least one uni-assist member university.\nChaudhary has obtained the following degree:\nSubject: Computer Science\nDegree: Bachelor of Engineering\nAverage mark: 2,2\nUniversity: University of Mumbai\nDate: 30.10.2020\nEvaluation:\nThese documents certify that Nadeem A
# ...

# %%
# Recursive split text by characters
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 100)
final_docs = text_splitter.split_documents(pdf_document)
final_docs
# Out:
# [Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk-java 3.2.2', 'creationdate': '2025-07-07T11:05:24+02:00', 'moddate': '2025-07-07T11:05:24+02:00', 'source': 'C:/Notes/ML-DL-GenAI/LangChain/Files/uni-assist.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Nadeem Athar Chaudhary\nBEI KHAN\nAlte Hellersdorfer Str 101\n12629 Berlin\nDEUTSCHLAND\nuni-assist Evaluation Report\nLastname : Chaudhary\nFirstname: Nadeem Athar\nDate of birth: 25.04.1998\nPlace of birth: Mumbai\nNationality: Indien\nApplicant number: 3328737\nThe above named applicant submitted a number of documents to uni-assist for preliminary\nevaluation as part of his or her application to at least one uni-assist member university.\nChaudhary has obtained the following degree:'),
# ...

# %%
from langchain_community.document_loaders import TextLoader
# Read the text file
loader= TextLoader('C:/Notes/ML-DL-GenAI/LangChain/Filesdata.txt')
# Convert the content into document
text_document = loader.load()
text_document
# Out:
# [Document(metadata={'source': 'C:/Notes/ML-DL-GenAI/LangChain/Files\\data.txt'}, page_content='Mein name ist Nadeem. Ich komme aus Indian. I bin student und have 4 jahr las softwareentwinkler erfahrung')]

# %%
text_data = ""
with open('C:/Notes/ML-DL-GenAI/LangChain/Files\data.txt') as file:
    text_data = file.read()
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 50, chunk_overlap=5)
final_text_docs = text_splitter.create_documents([text_data])
final_text_docs
# Out:
# Document(metadata={}, page_content='Mein name ist Nadeem. Ich komme aus Indian. I bin')
