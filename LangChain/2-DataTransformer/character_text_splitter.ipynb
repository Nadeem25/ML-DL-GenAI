# %%
from langchain_community.document_loaders import TextLoader
# Read the text file
loader= TextLoader('C:/Notes/ML-DL-GenAI/LangChain/Files\data.txt')
# Convert the content into document
text_document = loader.load()
text_document
# Out:
# [Document(metadata={'source': 'C:/Notes/ML-DL-GenAI/LangChain/Files\\data.txt'}, page_content='Mein name ist Nadeem. Ich komme aus Indian.\n\nI bin student und have 4 jahr las softwareentwinkler erfahrung')]

# %%
from langchain_text_splitters import CharacterTextSplitter
text_splitter = CharacterTextSplitter(separator="\n\n", chunk_size = 100, chunk_overlap = 20)
text_splitter.split_documents(text_document)
# Out:
# [Document(metadata={'source': 'C:/Notes/ML-DL-GenAI/LangChain/Files\\data.txt'}, page_content='Mein name ist Nadeem. Ich komme aus Indian.'),
#  Document(metadata={'source': 'C:/Notes/ML-DL-GenAI/LangChain/Files\\data.txt'}, page_content='I bin student und have 4 jahr las softwareentwinkler erfahrung')]
