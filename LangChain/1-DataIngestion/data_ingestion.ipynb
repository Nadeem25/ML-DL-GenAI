# %%
from langchain_community.document_loaders import TextLoader

# %%
# Read the text file
loader= TextLoader('data.txt')
# Convert the content into document
text_document = loader.load()
text_document
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='Mein name ist Nadeem')]

# %%
# Load and Read the pdf file
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('Nadeems_Full_Stack_Software_Engineer_Resume.pdf')
pdf_document = loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'Enhancv (https://www.enhancv.com)', 'creator': 'Enhancv', 'creationdate': '2025-07-10T12:28:18+00:00', 'moddate': '2025-07-10T12:28:19+00:00', 'ecv-data': '{"_id":"684dded12427057a1fcfd2b6","style":{"background":"b00","colors":["#002B7F","#80beee"],"columnLayoutOption":1,"fontBody":"roboto","fontHeading":"arimo","fontSize":4,"headerExtraSpacing":0,"isMetaDataDisabled":true,"layout":"ivyleague","layoutSize":"medium","lineHeightOption":1,"marginOption":1,"pageMarginOption":3,"record":"ResumeStyle"},"header":{"contacts":"","customHeight":188,"email":"25nadeemchaudhary.dev@gmail.com","extraField":"","extraLink":"","height":90,"link":"<a href=\\"https://www.linkedin.com/in/nadeem-software-engineer/\\" style=\\"text-decoration: underline;\\">LinkedIn</a>","location":"Berlin, Germany","name":"Nadeem chaudhary","phone":"+4915510862231","photo":"","photoStyle":"round","record":"Header","showEmail":true,"showExtraField":false,"showExtraLink":false,"showLink":true,"showLocation":true,"showPhone":true,"showPhoto":false,"showTitle":true,"title":"Full Stack Software Engineer","uppercaseName":true},"sections":[{"__t":"SummarySection","column":1,"enabled":true,"height":37,"items":[{"height":123,"id":"vh4og924hi","record":"SummaryItem","alignment":"left","text":"Result-oriented Full Stack Developer with 4 years of experience in designing and developing web applications and microservices. Proficient in Angular, Node.js, JavaScript, Typescript, and SQL, with hands-on expertise in REST APIs, CI/CD pipelines, and containerized deployments using Docker, with a strong track record of delivering high-quality software solutions. Demonstrated ability to work independently with a practical mindset, collaborating with engineers on software development projects, and eager to learn Agentic and Generative AI."}],"name":"","record":"SummarySection","showTitle":true},{"__t":"EducationSection","column":0,"enabled":true,"height":37,"items":[{"dateRange":{"fromMonth":3,"fromYear":2025,"isOngoing":true,"ongoingText":"","record":"DateRange","toMonth":null,"toYear":null},"height":59,"id":"l70hnxwrel","record":"EducationItem","alignment":"left","bullets":[""],"companyLogo":"https://logo.clearbit.com/berlin-international.de","degree":"Master\'s in Data Science","gpa":"","gpaText":"","institution":"International University of Applied Sciences","location":"","maxGpa":"","showBullets":false,"showDateRange":true,"showGpa":false,"showLocation":false},{"dateRange":{"fromMonth":7,"fromYear":2016,"isOngoing":false,"ongoingText":"","record":"DateRange","toMonth":9,"toYear":2020},"height":59,"id":"ji985zubtr","record":"EducationItem","alignment":"left","bullets":[""],"companyLogo":"https://logo.clearbit.com/mu.ac.in","degree":"Bachelor\'s of Engineering in Computer Science","gpa":"","gpaText":"","institution":"University of Mumbai","location":"","maxGpa":"","showBullets":false,"showDateRange":true,"showGpa":false,"showLocation":false}],"name":"","record":"EducationSection","showCompanyLogos":false,"timelineWidth":135},{"__t":"ExperienceSection","column":0,"enabled":true,"height":37,"items":[{"dateRange":{"fromMonth":10,"fromYear":2023,"isOngoing":false,"ongoingText":"","record":"DateRange","toMonth":3,"toYear":2025},"table":{"cols":2,"record":"TableItem","rows":[["<b>Project name</b>","<b>Description</b>"],["",""]]},"height":174,"id":"dqtf7ypc52","record":"ExperienceItem","alignment":"left","bullets":["Reduced operational costs by 5% by developing RESTful APIs to search and download CKYC data.","Automated data transfer using Cron Jobs in Node.js for seamless database synchronization.","Implemented real-time logging and monitoring using Loki and Grafana to keep track of system health and issues.","Configured CI/CD pipelines on Azure to streamline deployment and minimize manual errors.","Contributed in Agile ceremonies including sprint planning, task refinement, and user story writing using Jira."],"companyLogo":"https://logo.clearbit.com/nusummi ...
